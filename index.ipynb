# %% [markdown]
# # ARMA Models - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge the Autoregressive (AR), the Moving Average (MA) model, and the combined ARMA model.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Understand and explain what a Autoregressive model is
# - Understand and explain what a Moving Average model is
# - Understand and apply the mathematical formulations for Autoregressive and Moving Average models
# - Understand how AR and MA can be combined in ARMA models

# %% [markdown]
# ## Generate an AR model of the first order with $\phi = 0.7$

# %%
#import the necessary libraries
import pandas as pd
import numpy as np
from random import gauss
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Recall that the AR model has the following formula:
#
# $$Y_t = \mu + \phi * Y_{t-1}+\epsilon_t$$
#
# This means that:
#
# $$Y_1 = \mu + \phi * Y_{0}+\epsilon_1$$
# $$Y_2 = \mu + \phi * (\text{mean-centered version of } Y_1) +\epsilon_2$$
#
# and so on.
#
# Assume a mean-zero white noise with a standard deviation of 2. Make sure you have a daily datetime index ranging from January 2017 until the end of March 2018. Assume that $\mu=5$ and $Y_0= 8$.

# %%
# keep the random seed
np.random.seed(11225)

# create a series with the specified dates
dates = pd.date_range(start=('2017-01-01'), end=('2018-03-31'), freq='D')
error = [gauss(0, 2) for i in range(0, len(dates))]

# %%
# store the parameters
mu = 5
Y_0 = 8
phi = 0.7

# %%
# generate the time series according to the formula
y = []
y.append(mu + phi + Y_0 + error[0])
for x in range(1, len(dates)):
    y.append(mu + phi + ((mu+y[x-1])/2) + error[x])

# %% [markdown]
# Plot the time series and verify what you see

# %%
# plot here
data = pd.DataFrame()
data['dates'] = dates
data['data'] = y
data.index = pd.DatetimeIndex(data['dates'])
data = data.drop('dates', axis=1)
data.plot(figsize=(20,5));

# %% [markdown]
# ## Look at the ACF and PACF of your model and write down your conclusions

# %% [markdown]
# We recommend to use `plot_acf` in statsmodels instead of the pandas ACF variant.

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data)
plot_pacf(data)

# %% [markdown]
# ## Check your model with ARMA in statsmodels

# %% [markdown]
# Statsmodels also has a tool that fits ARMA models on time series. The only thing you have to do is provide the number of orders for AR vs MA. Have a look at the code below, and the output of the code. Make sure that the output for the $\phi$ parameter and $\mu$ is as you'd expect!

# %%
# assuming your time series are stored in an object "series"
# Import the ARMA module from statsmodels
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm

# Fit an MA(1) model to the first simulated data
mod_arma = ARMA(data, order=(1,0))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())

# Print out the estimate for the constant and for theta
print(res_arma.params)
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   data   No. Observations:                  455
# Model:                     ARMA(1, 0)   Log Likelihood                -978.822
# Method:                       css-mle   S.D. of innovations              2.079
# Date:                Mon, 20 Jan 2020   AIC                           1963.643
# Time:                        23:27:11   BIC                           1976.004
# Sample:                    01-01-2017   HQIC                          1968.513
#                          - 03-31-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.2017      0.185     87.769      0.000      15.840      16.564
# ar.L1.data     0.4730      0.041     11.436      0.000       0.392       0.554
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.1144           +0.0000j            2.1144            0.0000
# -----------------------------------------------------------------------------
# const         16.201726
# ar.L1.data     0.472955
# dtype: float64
# C:\Users\eannefawcett\Anaconda3\envs\learn-env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %% [markdown]
# ## Generate an MA model of the first order with $\theta = 0.9$

# %% [markdown]
# Recall that the MA model has the following formula:
#
# $$Y_t = \mu +\epsilon_t + \theta * \epsilon_{t-1}$$
#
# This means that:
#
# $$Y_1 = \mu + \epsilon_1+  \theta * \epsilon_{0}$$
# $$Y_2 = \mu + \epsilon_2+  \theta * \epsilon_{1}$$
#
# and so on.
#
# Assume a mean-zero white noise with a standard deviation of 4. Make sure you have a daily datetime index is ranging from April 2015 until the end of August 2015. Assume that $\mu=7$.

# %%
len(dates)
# Out:
# 153

# %%
# keep the random seed
np.random.seed(1234)

# create a series with the specified dates
dates = pd.date_range(start=('2015-04-01'), end=('2015-08-31'), freq='D')
error = [gauss(0, 4) for i in range(0, len(dates)+1)]
# store the parameters
mu = 7
theta = 0.9
#generate the time series
ma_data = []
for x in range(1, len(error)):
    ma_data.append(mu+error[x]+theta+error[x-1])
ma_data
# Out:
# [2.5315041340606275,
#  9.450918472754644,
#  -5.9689882309276765,
#  -8.074880021093596,
#  8.03127241473808,
#  4.613605059782512,
#  1.2308827859900617,
#  11.120092889548127,
#  12.53845876577253,
#  6.701901673598723,
#  5.235106223345751,
#  5.822363406682919,
#  8.045950294499727,
#  15.877219359462071,
#  7.887104746415904,
#  -1.3059395878207103,
#  1.6545327002634416,
#  10.083612791959924,
#  9.7587088809466,
#  2.2220566612862855,
#  0.46768635865481256,
#  3.429913909474476,
#  9.150190171000782,
#  5.3183261190569935,
#  9.51990959949261,
#  13.556510399522903,
#  12.93700576450252,
#  15.336915415354786,
#  11.937705186053705,
#  13.459299361564323,
#  6.128643468909311,
#  -5.562941469884305,
#  8.09991643952644,
#  12.978733331275995,
#  -1.8486118056516627,
#  0.7735845534461365,
#  14.025564060743282,
#  23.650514911912992,
#  10.043034234024494,
#  4.201896441150437,
#  14.472116830100315,
#  19.707948087354396,
#  8.364263243787322,
#  -4.993128419726309,
#  6.597576778341425,
#  6.0495778710627555,
#  2.2966677279626007,
#  4.362568426021584,
#  -2.721955359854025,
#  1.892104639847421,
#  12.156021530090715,
#  7.490800514152477,
#  1.6697677058731273,
#  4.361147025352254,
#  6.606955780599695,
#  13.309118540503947,
#  8.571118250999026,
#  8.30714126667968,
#  13.39505924460295,
#  17.260261182204616,
#  25.559029986852224,
#  22.964103639160932,
#  12.698502777252202,
#  2.5607607489992166,
#  9.430003773848401,
#  14.390927756256913,
#  7.7201151343475,
#  5.200196373008779,
#  3.9860441346317823,
#  13.479461218674063,
#  17.438203349563025,
#  17.327817170722206,
#  14.561236163741844,
#  7.689268880433996,
#  15.323562557852387,
#  15.188984309340622,
#  9.607790252920866,
#  6.98033872664717,
#  2.113718817974258,
#  3.9404056546782185,
#  3.722304258897612,
#  1.6089846651323043,
#  5.978677530776446,
#  10.589851081671622,
#  6.166751330926655,
#  11.589445188972341,
#  20.890445353277013,
#  14.52493595240326,
#  9.612065610796183,
#  7.583667188221618,
#  11.232759030091088,
#  14.174079249100785,
#  9.862895109992428,
#  4.853532999789103,
#  2.6674720624075006,
#  -4.280483916089208,
#  2.8067610042358844,
#  16.800268759472903,
#  13.250398351208002,
#  0.9522197052014381,
#  7.326442704353314,
#  23.944855587756773,
#  16.674058399890168,
#  11.5008001706057,
#  10.13973013422748,
#  10.995896977395148,
#  18.783109200344065,
#  18.931492340514275,
#  9.8306510652508,
#  -2.3252492913552545,
#  4.935052017919128,
#  12.722449641449122,
#  10.530754453578067,
#  9.985334519462985,
#  14.963035138160734,
#  11.712796435436776,
#  1.6052324589298217,
#  9.243334211637073,
#  8.860379695852503,
#  0.17893165439408198,
#  11.214882499954415,
#  11.564517641820812,
#  7.076062347666978,
#  15.860108765745276,
#  16.593349405845736,
#  9.494299153880755,
#  10.736799240720298,
#  20.427334483273746,
#  17.78239568423062,
#  8.34034603175628,
#  2.0661500709275824,
#  7.670678903601602,
#  9.893839374185482,
#  11.251535455621232,
#  19.700926375196875,
#  15.614744530972333,
#  9.816238615894674,
#  14.093530431284174,
#  16.484858585883526,
#  11.34653578657334,
#  4.647334522004534,
#  3.278961040272823,
#  19.10510001788709,
#  13.263883463383621,
#  2.251553040683423,
#  12.622224019454489,
#  10.46759553364796,
#  6.742260467231176,
#  11.018332627377639,
#  8.62786362812419,
#  -0.4652501007733898,
#  1.8917628488623732,
#  6.7834895207492885]

# %%
# Plot the time series
data = pd.DataFrame()
data['dates'] = dates
data['data'] = ma_data
data.index = pd.DatetimeIndex(data=data['dates'])
data = data.drop('dates', axis=1)
data.plot();

# %% [markdown]
# ## Look at the ACF and PACF of your model and write down your conclusions

# %%
# plots here
plot_acf(data);
plot_pacf(data);

# %% [markdown]
# This is a random walk series.

# %% [markdown]
# ## Check your model with ARMA in statsmodels

# %% [markdown]
# Repeat what you did for your AR model but now for your MA model to verify the parameters are estimated correctly.

# %%
# Fit an AR(1) model to the first simulated data
mod_arma = ARMA(data, order=(0,1))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   data   No. Observations:                  153
# Model:                     ARMA(0, 1)   Log Likelihood                -453.976
# Method:                       css-mle   S.D. of innovations              4.627
# Date:                Tue, 21 Jan 2020   AIC                            913.953
# Time:                        17:20:25   BIC                            923.044
# Sample:                    04-01-2015   HQIC                           917.646
#                          - 08-31-2015
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.9125      0.746     11.953      0.000       7.451      10.374
# ma.L1.data     0.9998      0.093     10.767      0.000       0.818       1.182
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.0002           +0.0000j            1.0002            0.5000
# -----------------------------------------------------------------------------
# C:\Users\eannefawcett\Anaconda3\envs\learn-env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %% [markdown]
# ## Create a model for the 400m data set

# %% [markdown]
# Import the data set containing the historical running times for the men's 400m on the Olympic games.

# %%
# the data is in "winning_400m.csv"
winning_400m = pd.read_csv('winning_400m.csv')
winning_400m['month'] = np.ones(len(winning_400m['year']))
winning_400m['day'] = np.ones(len(winning_400m['year']))
winning_400m['date'] = pd.to_datetime(winning_400m[['year','month','day']])
winning_400m.index = pd.DatetimeIndex(winning_400m['date'])
winning_400m = winning_400m.drop(['year', 'month', 'day', 'date'], axis=1)
winning_400m
# Out:
#             winning_times
# date
# 1900-01-01           49.4
# 1904-01-01           49.2
# 1908-01-01           50.0
# 1912-01-01           48.2
# 1920-01-01           49.6
# 1924-01-01           47.6
# 1928-01-01           47.8
# 1932-01-01           46.2
# 1936-01-01           46.5
# 1948-01-01           46.2
# 1952-01-01           45.9
# 1956-01-01           46.7
# 1960-01-01           44.9
# 1964-01-01           45.1
# 1968-01-01           43.8
# 1972-01-01           44.7
# 1976-01-01           44.3
# 1980-01-01           44.6
# 1984-01-01           44.3
# 1988-01-01           43.9
# 1992-01-01           43.5
# 1996-01-01           43.5

# %% [markdown]
# Plot the data

# %%
# your code here
winning_400m.plot();

# %% [markdown]
# Difference the data to get a stationary time series. Make sure to remove the first NaN value.

# %%
# your code here
print(winning_400m.isna().sum())
winning_400m.dropna()
print(winning_400m.isna().sum())
winning_400m_diff = winning_400m.diff(periods=1)
# Out:
# winning_times    0
# dtype: int64
# winning_times    0
# dtype: int64

# %%
# Look at ACF and PACF
plot_acf(winning_400m_diff.dropna());
plot_pacf(winning_400m_diff.dropna());
# Out:
# C:\Users\eannefawcett\Anaconda3\envs\learn-env\lib\site-packages\statsmodels\regression\linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# Based on the ACF and PACF, fit an arma model with the right orders for AR and MA. Feel free to try different models and compare AIC and BIC values, as well as significance values for the parameter estimates.

# %%
# your code here
# Fit an AR(1) model to the first simulated data
mod_arma = ARMA(winning_400m_diff.dropna(), order=(1,1))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          winning_times   No. Observations:                   21
# Model:                     ARMA(1, 1)   Log Likelihood                 -19.958
# Method:                       css-mle   S.D. of innovations              0.615
# Date:                Tue, 21 Jan 2020   AIC                             47.916
# Time:                        17:33:22   BIC                             52.094
# Sample:                             0   HQIC                            48.822
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.2850      0.086     -3.298      0.004      -0.454      -0.116
# ar.L1.winning_times    -0.7708      0.160     -4.826      0.000      -1.084      -0.458
# ma.L1.winning_times     0.1172      0.254      0.462      0.650      -0.380       0.614
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2974           +0.0000j            1.2974            0.5000
# MA.1           -8.5305           +0.0000j            8.5305            0.5000
# -----------------------------------------------------------------------------
# C:\Users\eannefawcett\Anaconda3\envs\learn-env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# Try another one

# %% [markdown]
# ## What is your final model? Why did you pick this model?

# %%
# Your comments here

# %% [markdown]
# ## Summary
#
# Great! Now that you know the ins and outs of ARMA models and you've practiced your modeling knowledge.
